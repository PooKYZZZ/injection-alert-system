# %% [markdown]
# # Script-first training
#
# This notebook is a presentation and control surface. The reusable training implementation lives in `ml_model/training/`; no training loop or model definition is duplicated here.
#
# Run the CPU-safe preparation profile first, then change the configuration only when the environment is ready for a full run.

# %%
from ml_model.training.config import TrainingConfig
from ml_model.training.train import run_training
from ml_model.training.paths import resolve_project_root

project_root = resolve_project_root()
config = TrainingConfig.smoke()
config

# %%
run_dir = run_training(config)
print(f"Run directory: {run_dir}")

# %% [markdown]
# For a full experiment, use a checked-in TOML preset from `ml_model/configs/training/` with the command-line entrypoint. Generated results remain outside Git.
